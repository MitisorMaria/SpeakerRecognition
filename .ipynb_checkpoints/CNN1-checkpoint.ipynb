# %%
import signal_processing, data_load, learn, evaluate
# Out:
# Using TensorFlow backend.

# %%
num_rows = 45
num_columns = 2900
num_channels = 1

num_epochs = 10
num_batch_size = 121
num_speakers = 2

# %%
featuresdf = data_load.make_dataframe(num_speakers, './Dataset/wav/', num_rows, num_columns)
# Out:
# Finished feature extraction from  208  files

# %%
result_sets = data_load.make_train_test_sets(featuresdf, num_rows, num_columns, num_channels)
num_labels = result_sets[4]
model = learn.build_CNN_model(num_rows, num_columns, num_labels)

# %%
learn.compile(model)

# %%
result_sets[1].shape
# Out:
# (42, 45, 2900, 1)

# %%
evaluate.evaluate_before_training(model, result_sets[0], result_sets[2])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 44, 2899, 16)      80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 1449, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 1449, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 1448, 32)      2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 724, 32)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 724, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 723, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 361, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 361, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 360, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 180, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 180, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 166/166 [==============================] - 4s 22ms/sample - loss: 0.7627 - accuracy: 0.6084
# Pre-training accuracy: 60.8434%

# %%
history = learn.train_model(model, result_sets, num_epochs, num_batch_size, 'CNN1', 'default', 'CNN1')
# Out:
# Train on 166 samples, validate on 42 samples
# Epoch 1/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.0282 - accuracy: 0.5950
# Epoch 00001: val_loss improved from inf to 0.93841, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 14s 81ms/sample - loss: 1.0898 - accuracy: 0.5241 - val_loss: 0.9384 - val_accuracy: 0.3095
# Epoch 2/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.9074 - accuracy: 0.4132
# Epoch 00002: val_loss improved from 0.93841 to 0.66945, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 13s 80ms/sample - loss: 0.8612 - accuracy: 0.4096 - val_loss: 0.6695 - val_accuracy: 0.6905
# Epoch 3/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.7697 - accuracy: 0.6281
# Epoch 00003: val_loss improved from 0.66945 to 0.63522, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 14s 85ms/sample - loss: 0.8573 - accuracy: 0.6145 - val_loss: 0.6352 - val_accuracy: 0.6905
# Epoch 4/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.8154 - accuracy: 0.6281
# Epoch 00004: val_loss did not improve from 0.63522
# 166/166 [==============================] - 14s 84ms/sample - loss: 0.7776 - accuracy: 0.6145 - val_loss: 0.6636 - val_accuracy: 0.4762
# Epoch 5/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.6094 - accuracy: 0.7603
# Epoch 00005: val_loss did not improve from 0.63522
# 166/166 [==============================] - 15s 89ms/sample - loss: 0.6089 - accuracy: 0.6988 - val_loss: 0.7287 - val_accuracy: 0.3095
# Epoch 6/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.7024 - accuracy: 0.4298
# Epoch 00006: val_loss did not improve from 0.63522
# 166/166 [==============================] - 13s 78ms/sample - loss: 0.7022 - accuracy: 0.4217 - val_loss: 0.6902 - val_accuracy: 0.3095
# Epoch 7/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.6714 - accuracy: 0.4380
# Epoch 00007: val_loss improved from 0.63522 to 0.58990, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 13s 77ms/sample - loss: 0.6384 - accuracy: 0.5120 - val_loss: 0.5899 - val_accuracy: 0.8333
# Epoch 8/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.5278 - accuracy: 0.9091
# Epoch 00008: val_loss improved from 0.58990 to 0.51732, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 13s 79ms/sample - loss: 0.5270 - accuracy: 0.8855 - val_loss: 0.5173 - val_accuracy: 1.0000
# Epoch 9/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.5525 - accuracy: 0.6777
# Epoch 00009: val_loss improved from 0.51732 to 0.48009, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 14s 85ms/sample - loss: 0.5386 - accuracy: 0.7108 - val_loss: 0.4801 - val_accuracy: 1.0000
# Epoch 10/10
# 121/166 [====================>.........] - ETA: 3s - loss: 0.4960 - accuracy: 0.7355
# Epoch 00010: val_loss improved from 0.48009 to 0.46727, saving model to saved_models/weights.best.CNN1.hdf5
# 166/166 [==============================] - 14s 86ms/sample - loss: 0.5000 - accuracy: 0.7410 - val_loss: 0.4673 - val_accuracy: 0.9524
# Training completed in time:  0:02:17.382675

# %%
evaluate.evaluate_model(model, result_sets)
# Out:
# Training Accuracy:  0.93373495
# Testing Accuracy:  0.95238096

# %%
evaluate.display_metrics(model, result_sets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        13
#            1       1.00      0.93      0.96        29
#
#     accuracy                           0.95        42
#    macro avg       0.93      0.97      0.95        42
# weighted avg       0.96      0.95      0.95        42
#
# Confusion matrix:
# [[13  0]
#  [ 2 27]]

# %%
evaluate.plot_history(history)

# %%
modelReg = learn.build_regularized_CNN_model(num_rows, num_columns, num_labels)
learn.compile(modelReg)
reg_history= learn.train_model(modelReg, result_sets, num_epochs, num_batch_size, 'CNN1Reg', 'regularization', 'CNN1Reg')
# Out:
# Train on 166 samples, validate on 42 samples
# Epoch 1/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.9926 - accuracy: 0.3967
# Epoch 00001: val_loss improved from inf to 1.88017, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 14s 84ms/sample - loss: 2.0736 - accuracy: 0.4639 - val_loss: 1.8802 - val_accuracy: 0.6905
# Epoch 2/10
# 121/166 [====================>.........] - ETA: 3s - loss: 2.0434 - accuracy: 0.6198
# Epoch 00002: val_loss did not improve from 1.88017
# 166/166 [==============================] - 13s 81ms/sample - loss: 2.0302 - accuracy: 0.5602 - val_loss: 2.0484 - val_accuracy: 0.3095
# Epoch 3/10
# 121/166 [====================>.........] - ETA: 3s - loss: 2.1298 - accuracy: 0.3967
# Epoch 00003: val_loss did not improve from 1.88017
# 166/166 [==============================] - 15s 90ms/sample - loss: 2.1149 - accuracy: 0.3855 - val_loss: 1.9109 - val_accuracy: 0.3095
# Epoch 4/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.8873 - accuracy: 0.4215
# Epoch 00004: val_loss improved from 1.88017 to 1.82209, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 88ms/sample - loss: 1.8748 - accuracy: 0.4759 - val_loss: 1.8221 - val_accuracy: 0.6905
# Epoch 5/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.8676 - accuracy: 0.6612
# Epoch 00005: val_loss improved from 1.82209 to 1.79949, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 89ms/sample - loss: 1.9045 - accuracy: 0.6145 - val_loss: 1.7995 - val_accuracy: 0.6905
# Epoch 6/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.8882 - accuracy: 0.6198
# Epoch 00006: val_loss improved from 1.79949 to 1.78942, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 91ms/sample - loss: 1.8659 - accuracy: 0.6145 - val_loss: 1.7894 - val_accuracy: 0.8095
# Epoch 7/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.7835 - accuracy: 0.6694
# Epoch 00007: val_loss improved from 1.78942 to 1.78806, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 91ms/sample - loss: 1.7761 - accuracy: 0.7289 - val_loss: 1.7881 - val_accuracy: 0.7381
# Epoch 8/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.7639 - accuracy: 0.6612
# Epoch 00008: val_loss improved from 1.78806 to 1.76467, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 89ms/sample - loss: 1.7584 - accuracy: 0.6265 - val_loss: 1.7647 - val_accuracy: 0.6190
# Epoch 9/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.7553 - accuracy: 0.4793
# Epoch 00009: val_loss improved from 1.76467 to 1.71648, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 14s 87ms/sample - loss: 1.7446 - accuracy: 0.5181 - val_loss: 1.7165 - val_accuracy: 0.9524
# Epoch 10/10
# 121/166 [====================>.........] - ETA: 3s - loss: 1.6956 - accuracy: 0.8182
# Epoch 00010: val_loss improved from 1.71648 to 1.66523, saving model to saved_models/weights.best.CNN1Reg.hdf5
# 166/166 [==============================] - 15s 89ms/sample - loss: 1.6869 - accuracy: 0.8253 - val_loss: 1.6652 - val_accuracy: 0.9762
# Training completed in time:  0:02:26.457149

# %%
evaluate.plot_history(reg_history)

# %%
evaluate.plot_compared_val_loss(history, reg_history, 'default', 'regularization L2')
