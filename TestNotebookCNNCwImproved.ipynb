# %%
import evaluate, learn, signal_processing, data_load
# Out:
# Using TensorFlow backend.

# %%
num_rows = 45
num_columns = 130
num_channels = 1

fine_tune_at = 300

num_epochs = 100
num_batch_size = 13
num_speakers = 10
num_seconds = 3.0
num_labels = 10

# %%
model = learn.build_CNN_model(num_rows, num_columns, num_labels)
#base_model = learn.get_densenet(num_rows, num_columns, num_channels, num_labels, fine_tune_at)
#model = learn.build_model_densenet(base_model, num_labels)

# %%
model.load_weights("saved_models/weights.best.CNNCwImproved.hdf5")
#model.load_weights("saved_models/weights.best.DenseNet1.hdf5")

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

# Convert features and corresponding classification labels into numpy arrays
y = np.array(['A.J._Buckley', 'A.R._Rahman', 'Aamir_Khan', 'Aaron_Tveit', 'Aaron_Yoo', 'Abbie_Cornish', 'Abigail_Breslin', 
             'Abigail_Spencer', 'Adam_Beach', 'Adam_Brody'])

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

def print_prediction(file_name, model, num_rows, num_columns, num_channels, num_seconds):
    prediction_feature = signal_processing.extract_features_mfcc_seconds(file_name, num_rows, num_columns, num_seconds)
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
for i in range (1, 12):
    print_prediction('./test_clips/abbie_cornish/2/test_abbie_cornish' + str(i) + '.wav', model, num_rows, num_columns, num_channels, num_seconds)
# Out:
# The predicted class is: Abbie_Cornish
#
# A.J._Buckley 		 :  0.00006188124098116531968116760254
# A.R._Rahman 		 :  0.00000982792062131920829415321350
# Aamir_Khan 		 :  0.00144621683284640312194824218750
# Aaron_Tveit 		 :  0.12303405255079269409179687500000
# Aaron_Yoo 		 :  0.00201537809334695339202880859375
# Abbie_Cornish 		 :  0.87035989761352539062500000000000
# Abigail_Breslin 		 :  0.00000089980704842673731036484241
# Abigail_Spencer 		 :  0.00237454962916672229766845703125
# Adam_Beach 		 :  0.00069481326499953866004943847656
# Adam_Brody 		 :  0.00000242299347519292496144771576
# The predicted class is: Abbie_Cornish
#
# A.J._Buckley 		 :  0.00000050449750688130734488368034
# A.R._Rahman 		 :  0.00000775288935983553528785705566
# Aamir_Khan 		 :  0.02661346644163131713867187500000
# Aaron_Tveit 		 :  0.03749973326921463012695312500000
# Aaron_Yoo 		 :  0.00088100554421544075012207031250
# Abbie_Cornish 		 :  0.93015205860137939453125000000000
# ...

# %%
for i in range (1, 12):
    print_prediction('./test_clips/aaron_tveit/1/test_aaron_tveit' + str(i) + '.wav', model, num_rows, num_columns, num_channels, num_seconds)
# Out:
# The predicted class is:
+ str(i) + '.wav', model, num_rows, num_columns, num_channels, num_seconds)
# Out:
# The predicted class is: Aaron_Tveit
#
# A.J._Buckley 		 :  0.00013742755982093513011932373047
# A.R._Rahman 		 :  0.00000325438531945110298693180084
# Aamir_Khan 		 :  0.00000207642824534559622406959534
# Aaron_Tveit 		 :  0.85420447587966918945312500000000
# Aaron_Yoo 		 :  0.03347177058458328247070312500000
# Abbie_Cornish 		 :  0.00404945341870188713073730468750
# Abigail_Breslin 		 :  0.00420966092497110366821289062500
# Abigail_Spencer 		 :  0.00000386911096939002163708209991
# Adam_Beach 		 :  0.03915350139141082763671875000000
# Adam_Brody 		 :  0.06476462632417678833007812500000
# The predicted class is: Aaron_Tveit
#
# A.J._Buckley 		 :  0.00000050757927283484605140984058
# A.R._Rahman 		 :  0.00000040410745327790209557861090
# Aamir_Khan 		 :  0.00056194193894043564796447753906
# Aaron_Tveit 		 :  0.76746052503585815429687500000000
# Aaron_Yoo 		 :  0.00009781970584299415349960327148
# Abbie_Cornish 		 :  0.00196407386101782321929931640625
# ...

# %%
for i in range (1, 12):
    print_prediction('./test_clips/a_j_buckley/1/test_a_j_buckley' + str(i) + '.wav', model, num_rows, num_columns, num_channels, num_seconds)
# Out:
# The predicted class is: Adam_Beach
#
# A.J._Buckley 		 :  0.00018325261771678924560546875000
# A.R._Rahman 		 :  0.00000059482749747985508292913437
# Aamir_Khan 		 :  0.00116052513476461172103881835938
# Aaron_Tveit 		 :  0.00127422704827040433883666992188
# Aaron_Yoo 		 :  0.12526161968708038330078125000000
# Abbie_Cornish 		 :  0.00003954620842705480754375457764
# Abigail_Breslin 		 :  0.00000014413095072995929513126612
# Abigail_Spencer 		 :  0.00019103821250610053539276123047
# Adam_Beach 		 :  0.87172555923461914062500000000000
# Adam_Brody 		 :  0.00016352524107787758111953735352
# The predicted class is: Aaron_Tveit
#
# A.J._Buckley 		 :  0.00000111066162844508653506636620
# A.R._Rahman 		 :  0.00000798720611783210188150405884
# Aamir_Khan 		 :  0.00156783987767994403839111328125
# Aaron_Tveit 		 :  0.97640049457550048828125000000000
# Aaron_Yoo 		 :  0.00030019914265722036361694335938
# Abbie_Cornish 		 :  0.01931804977357387542724609375000
# ...

# %%
for i in range (1, 12):
    print_prediction('./test_clips/a_r_rahman/3/test_a_r_rahman' + str(i) + '.wav', model, num_rows, num_columns, num_channels, num_seconds)
# Out:
# The predicted class is: A.R._Rahman
#
# A.J._Buckley 		 :  0.00000060283838365648989565670490
# A.R._Rahman 		 :  0.91520220041275024414062500000000
# Aamir_Khan 		 :  0.06164626032114028930664062500000
# Aaron_Tveit 		 :  0.00003625372482929378747940063477
# Aaron_Yoo 		 :  0.00651963660493493080139160156250
# Abbie_Cornish 		 :  0.00000000595667337677241448545828
# Abigail_Breslin 		 :  0.00000000005320308429923592541400
# Abigail_Spencer 		 :  0.00001263117883354425430297851562
# Adam_Beach 		 :  0.00017361274512950330972671508789
# Adam_Brody 		 :  0.01640886627137660980224609375000
# The predicted class is: A.R._Rahman
#
# A.J._Buckley 		 :  0.00000026202431513411283958703279
# A.R._Rahman 		 :  0.98898178339004516601562500000000
# Aamir_Khan 		 :  0.00762413209304213523864746093750
# Aaron_Tveit 		 :  0.00037057627923786640167236328125
# Aaron_Yoo 		 :  0.00298515334725379943847656250000
# Abbie_Cornish 		 :  0.00000000662543797602666018065065
# ...
