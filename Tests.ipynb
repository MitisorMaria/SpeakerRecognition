# %%
import pandas as pd
import os
import librosa


# TensorFlow and tf.keras
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
file_name = 'C:/Users/Maria/Documents/Licenta/Proiect/Dataset/wav/id10001/9mQ11vBs1wc/00003.wav'
audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=7.0) 
print(audio)
# Out:
# [0.00119326 0.00180144 0.00157859 ... 0.10684577 0.08739133 0.        ]

# %%
audio.size
# Out:
# 115544

# %%
audio = audio[:115544]

# %%
import IPython.display as ipd
ipd.Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(audio, rate=33050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
